# %%
import pandas as pd
import numpy as np

krx_data = pd.read_parquet(
    '../data_lake/raw/index/korea_index.parquet'
)

# %%
krx_data
# Out:
#        base_date release_date      time  time_zone      symbol exchange  \
# 0     1980-01-04   1980-01-04  15:30:00  UTC+09:00       KOSPI      KRX
# 1     1980-01-07   1980-01-07  15:30:00  UTC+09:00       KOSPI      KRX
# 2     1980-01-08   1980-01-08  15:30:00  UTC+09:00       KOSPI      KRX
# 3     1980-01-09   1980-01-09  15:30:00  UTC+09:00       KOSPI      KRX
# 4     1980-01-10   1980-01-10  15:30:00  UTC+09:00       KOSPI      KRX
# ...          ...          ...       ...        ...         ...      ...
# 95503 2026-06-12   2026-06-12  15:30:00  UTC+09:00  KRXSECTOR3      KRX
# 95504 2026-06-12   2026-06-12  15:30:00  UTC+09:00  KRXSECTOR4      KRX
# 95505 2026-06-12   2026-06-12  15:30:00  UTC+09:00  KRXSECTOR6      KRX
# 95506 2026-06-12   2026-06-12  15:30:00  UTC+09:00  KRXSECTOR7      KRX
# 95507 2026-06-12   2026-06-12  15:30:00  UTC+09:00  KRXSECTOR9      KRX
#
#            country     open     high      low    close  volume
# ...

# %%
tse_data = pd.read_parquet(
    '../data_lake/raw/index/japan_index.parquet'
)

# %%
tse_data.columns
# Out:
# Index(['base_date', 'release_date', 'time', 'time_zone', 'symbol', 'exchange',
#        'country', 'open', 'high', 'low', 'close', 'volume'],
#       dtype='str')

# %%
china_data = pd.read_parquet(
    '../data_lake/raw/index/china_index.parquet'
)

# %%
china_data[china_data['symbol'] == 'HSI']['close'].plot()
# Out:
# <Axes: >

# %%
uscpi = pd.read_parquet(
    '../data_lake/raw/macro/USA/USCPI_YoY.parquet'
)

# %%
uscpi
# Out:
#      base_date release_date      time time_zone  symbol exchange  \
# 0   1969-12-01   1970-01-19  08:30:00     UTC-5  CPIYOY      BOL
# 1   1970-01-01   1970-02-19  08:30:00     UTC-5  CPIYOY      BOL
# 2   1970-02-01   1970-03-20  08:30:00     UTC-5  CPIYOY      BOL
# 3   1970-03-01   1970-04-22  08:30:00     UTC-4  CPIYOY      BOL
# 4   1970-04-01   1970-05-20  08:30:00     UTC-4  CPIYOY      BOL
# ..         ...          ...       ...       ...     ...      ...
# 671 2025-12-01   2026-01-13  08:30:00     UTC-5  CPIYOY      BOL
# 672 2026-01-01   2026-02-13  08:30:00     UTC-5  CPIYOY      BOL
# 673 2026-02-01   2026-03-11  08:30:00     UTC-4  CPIYOY      BOL
# 674 2026-03-01   2026-04-10  08:30:00     UTC-4  CPIYOY      BOL
# 675 2026-04-01   2026-05-12  08:30:00     UTC-4  CPIYOY      BOL
#
#            country  actual  forecast  previous
# 0    United States   0.062       NaN       NaN
# 1    United States   0.062       NaN     0.062
# ...

# %%
napmpmi = pd.read_parquet(
    '../data_lake/raw/macro/USA/NAPMPMI.parquet'
)

# %%
jpcpi = pd.read_parquet(
    '../data_lake/raw/macro/Japan/JPCPIYOY.parquet'
)

# %%
jpcpi
# Out:
#      base_date release_date      time time_zone    symbol exchange country  \
# 0   1971-01-01   1971-02-26  08:30:00     UTC+9  JPCPIYOY    INDEX   Japan
# 1   1971-02-01   1971-03-26  08:30:00     UTC+9  JPCPIYOY    INDEX   Japan
# 2   1971-03-01   1971-04-30  08:30:00     UTC+9  JPCPIYOY    INDEX   Japan
# 3   1971-04-01   1971-05-28  08:30:00     UTC+9  JPCPIYOY    INDEX   Japan
# 4   1971-05-01   1971-06-25  08:30:00     UTC+9  JPCPIYOY    INDEX   Japan
# ..         ...          ...       ...       ...       ...      ...     ...
# 658 2025-11-01   2025-12-19  08:30:00     UTC+9  JPCPIYOY    INDEX   Japan
# 659 2025-12-01   2026-01-23  08:30:00     UTC+9  JPCPIYOY    INDEX   Japan
# 660 2026-01-01   2026-02-20  08:30:00     UTC+9  JPCPIYOY    INDEX   Japan
# 661 2026-02-01   2026-03-24  08:30:00     UTC+9  JPCPIYOY    INDEX   Japan
# 662 2026-03-01   2026-04-24  08:30:00     UTC+9  JPCPIYOY    INDEX   Japan
#
#      actual  forecast  previous
# 0     0.065       NaN       NaN
# ...
